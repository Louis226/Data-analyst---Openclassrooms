# %% [markdown]
# <h1>Table de matière<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importation-des-données" data-toc-modified-id="Importation-des-données-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importation des données</a></span></li><li><span><a href="#Nettoyage-des-données" data-toc-modified-id="Nettoyage-des-données-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Nettoyage des données</a></span><ul class="toc-item"><li><span><a href="#Vérification-de-corrélation-entre-les-variables" data-toc-modified-id="Vérification-de-corrélation-entre-les-variables-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Vérification de corrélation entre les variables</a></span></li><li><span><a href="#Création-de-modèle-régression-linéaire" data-toc-modified-id="Création-de-modèle-régression-linéaire-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Création de modèle régression linéaire</a></span><ul class="toc-item"><li><span><a href="#Régression-linéaire-avec-la-librairie-Sklearn" data-toc-modified-id="Régression-linéaire-avec-la-librairie-Sklearn-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Régression linéaire avec la librairie Sklearn</a></span></li><li><span><a href="#Régression-linéaire-avec-la-librairie-Statsmodels" data-toc-modified-id="Régression-linéaire-avec-la-librairie-Statsmodels-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Régression linéaire avec la librairie Statsmodels</a></span></li></ul></li><li><span><a href="#Remplacement-des-valeurs-manquantes" data-toc-modified-id="Remplacement-des-valeurs-manquantes-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Remplacement des valeurs manquantes</a></span></li></ul></li><li><span><a href="#ACP-et-K-Means" data-toc-modified-id="ACP-et-K-Means-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ACP et K-Means</a></span><ul class="toc-item"><li><span><a href="#ACP-Analyse" data-toc-modified-id="ACP-Analyse-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>ACP Analyse</a></span><ul class="toc-item"><li><span><a href="#Préparation-des-données-centrées-et-réduites" data-toc-modified-id="Préparation-des-données-centrées-et-réduites-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Préparation des données centrées et réduites</a></span></li><li><span><a href="#Éboulis-des-valeurs-propres" data-toc-modified-id="Éboulis-des-valeurs-propres-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Éboulis des valeurs propres</a></span></li><li><span><a href="#Cercle-de-corrélation" data-toc-modified-id="Cercle-de-corrélation-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Cercle de corrélation</a></span></li><li><span><a href="#Projection-des-individus-sur-le-plan-factoriel-selon-le-type-de-billet" data-toc-modified-id="Projection-des-individus-sur-le-plan-factoriel-selon-le-type-de-billet-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Projection des individus sur le plan factoriel selon le type de billet</a></span></li></ul></li><li><span><a href="#Kmeans-Analyse" data-toc-modified-id="Kmeans-Analyse-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Kmeans Analyse</a></span><ul class="toc-item"><li><span><a href="#Récupération-des-clusters-attribués-à-chaque-individu" data-toc-modified-id="Récupération-des-clusters-attribués-à-chaque-individu-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Récupération des clusters attribués à chaque individu</a></span></li><li><span><a href="#Comparaison-de-moyen-des-variables-entre-clusters-et-le-type-de-billet" data-toc-modified-id="Comparaison-de-moyen-des-variables-entre-clusters-et-le-type-de-billet-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Comparaison de moyen des variables entre clusters et le type de billet</a></span></li><li><span><a href="#Projection-des-individus-sur-le-premier-plan-factoriel-par-clusters" data-toc-modified-id="Projection-des-individus-sur-le-premier-plan-factoriel-par-clusters-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Projection des individus sur le premier plan factoriel par clusters</a></span></li><li><span><a href="#Matrice-de-confusion-Kmeans" data-toc-modified-id="Matrice-de-confusion-Kmeans-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Matrice de confusion Kmeans</a></span></li><li><span><a href="#Tester-les-billets-inconnus" data-toc-modified-id="Tester-les-billets-inconnus-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Tester les billets inconnus</a></span><ul class="toc-item"><li><span><a href="#Importation-des-données-de-test" data-toc-modified-id="Importation-des-données-de-test-3.2.5.1"><span class="toc-item-num">3.2.5.1&nbsp;&nbsp;</span>Importation des données de test</a></span></li><li><span><a href="#Combiner-les-données-inconnues-avec-les-données-d'origine" data-toc-modified-id="Combiner-les-données-inconnues-avec-les-données-d'origine-3.2.5.2"><span class="toc-item-num">3.2.5.2&nbsp;&nbsp;</span>Combiner les données inconnues avec les données d'origine</a></span></li><li><span><a href="#Préparation-des-données-de-test-(centrées-et-réduites)" data-toc-modified-id="Préparation-des-données-de-test-(centrées-et-réduites)-3.2.5.3"><span class="toc-item-num">3.2.5.3&nbsp;&nbsp;</span>Préparation des données de test (centrées et réduites)</a></span></li><li><span><a href="#Projection-des-individus-d'origine-par-clusters,-et-les-individus-inconnus-sur-le-plan-factoriel" data-toc-modified-id="Projection-des-individus-d'origine-par-clusters,-et-les-individus-inconnus-sur-le-plan-factoriel-3.2.5.4"><span class="toc-item-num">3.2.5.4&nbsp;&nbsp;</span>Projection des individus d'origine par clusters, et les individus inconnus sur le plan factoriel</a></span></li><li><span><a href="#Prédiction-par-Kmeans" data-toc-modified-id="Prédiction-par-Kmeans-3.2.5.5"><span class="toc-item-num">3.2.5.5&nbsp;&nbsp;</span>Prédiction par Kmeans</a></span></li><li><span><a href="#Calcul-de-la-distance-entre-chaque-billet-inconnu-et-le-centre-des-clusters" data-toc-modified-id="Calcul-de-la-distance-entre-chaque-billet-inconnu-et-le-centre-des-clusters-3.2.5.6"><span class="toc-item-num">3.2.5.6&nbsp;&nbsp;</span>Calcul de la distance entre chaque billet inconnu et le centre des clusters</a></span></li></ul></li></ul></li><li><span><a href="#Script-de-modèle-de-détection-Kmeans" data-toc-modified-id="Script-de-modèle-de-détection-Kmeans-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Script de modèle de détection Kmeans</a></span></li></ul></li><li><span><a href="#Régression-logistique" data-toc-modified-id="Régression-logistique-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Régression logistique</a></span><ul class="toc-item"><li><span><a href="#Régression-logistique-avec-la-librairie-Sklearn" data-toc-modified-id="Régression-logistique-avec-la-librairie-Sklearn-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Régression logistique avec la librairie Sklearn</a></span><ul class="toc-item"><li><span><a href="#Séparation-des-données-d'entraînement-et-de-test" data-toc-modified-id="Séparation-des-données-d'entraînement-et-de-test-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Séparation des données d'entraînement et de test</a></span></li><li><span><a href="#Création-de-modèle-régression-logistique" data-toc-modified-id="Création-de-modèle-régression-logistique-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Création de modèle régression logistique</a></span></li><li><span><a href="#Évaluation-du-modèle-avec-les-données-de-test" data-toc-modified-id="Évaluation-du-modèle-avec-les-données-de-test-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Évaluation du modèle avec les données de test</a></span></li><li><span><a href="#Matrice-de-confusion-régression-logistique" data-toc-modified-id="Matrice-de-confusion-régression-logistique-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Matrice de confusion régression logistique</a></span></li><li><span><a href="#Coefficient-régression-logistique" data-toc-modified-id="Coefficient-régression-logistique-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Coefficient régression logistique</a></span></li></ul></li><li><span><a href="#Script-de-modèle-de-détection-régression-logistique---1" data-toc-modified-id="Script-de-modèle-de-détection-régression-logistique---1-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Script de modèle de détection régression logistique - 1</a></span></li><li><span><a href="#Régression-logistique-avec-la-librairie-Statsmodels" data-toc-modified-id="Régression-logistique-avec-la-librairie-Statsmodels-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Régression logistique avec la librairie Statsmodels</a></span><ul class="toc-item"><li><span><a href="#Séparation-des-données-d'entraînement-et-de-test" data-toc-modified-id="Séparation-des-données-d'entraînement-et-de-test-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Séparation des données d'entraînement et de test</a></span></li><li><span><a href="#Création-de-modèle-régression-logistique" data-toc-modified-id="Création-de-modèle-régression-logistique-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Création de modèle régression logistique</a></span></li><li><span><a href="#Évaluation-du-modèle-avec-les-données-de-test" data-toc-modified-id="Évaluation-du-modèle-avec-les-données-de-test-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Évaluation du modèle avec les données de test</a></span></li><li><span><a href="#Matrice-de-confusion-régression-logistique" data-toc-modified-id="Matrice-de-confusion-régression-logistique-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Matrice de confusion régression logistique</a></span></li></ul></li><li><span><a href="#Script-de-modèle-de-détection-régression-logistique---2" data-toc-modified-id="Script-de-modèle-de-détection-régression-logistique---2-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Script de modèle de détection régression logistique - 2</a></span></li></ul></li><li><span><a href="#K-Nearest-Neighbors-(K-NN)" data-toc-modified-id="K-Nearest-Neighbors-(K-NN)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>K Nearest Neighbors (K-NN)</a></span><ul class="toc-item"><li><span><a href="#Séparation-des-données-d'entraînement-et-de-test" data-toc-modified-id="Séparation-des-données-d'entraînement-et-de-test-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Séparation des données d'entraînement et de test</a></span></li><li><span><a href="#Calcul-le-nombre-optimal-de-K" data-toc-modified-id="Calcul-le-nombre-optimal-de-K-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Calcul le nombre optimal de K</a></span></li><li><span><a href="#Création-de-modèle-5-NN" data-toc-modified-id="Création-de-modèle-5-NN-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Création de modèle 5-NN</a></span></li><li><span><a href="#Évaluation-du-modèle-avec-les-données-de-test" data-toc-modified-id="Évaluation-du-modèle-avec-les-données-de-test-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Évaluation du modèle avec les données de test</a></span></li><li><span><a href="#Matrice-de-confusion-K-NN" data-toc-modified-id="Matrice-de-confusion-K-NN-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Matrice de confusion K-NN</a></span></li><li><span><a href="#Script-de-modèle-de-détection-K-NN" data-toc-modified-id="Script-de-modèle-de-détection-K-NN-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Script de modèle de détection K-NN</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.cluster import KMeans
from sklearn import decomposition, preprocessing, linear_model
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.metrics import accuracy_score, r2_score
import statsmodels.api as sm

# %% [markdown]
# # Importation des données

# %%
# Importation des données
data = pd.read_csv(
    'Desktop/Openclassrooms/P10_Shibin_YANG/billets.csv', sep=';')

# %%
data
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %%
# Valeur manquante pour la variable 'margin_low'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
# Vérification des lignes qui ont les valeurs manquantes dans la colonne margin_low
Null = data[data['margin_low'].isnull()]
Null
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72          True    171.94       103.89        103.45         NaN       3.25
# 99          True    171.93       104.07        104.18         NaN       3.14
# 151         True    172.07       103.80        104.38         NaN       3.02
# 197         True    171.45       103.66        103.80         NaN       3.62
# 241         True    171.83       104.14        104.06         NaN       3.02
# 251         True    171.80       103.26        102.82         NaN       2.95
# 284         True    171.92       103.83        103.76         NaN       3.23
# 334         True    171.85       103.70        103.96         NaN       3.00
# 410         True    172.56       103.72        103.51         NaN       3.12
# 413         True    172.30       103.66        103.50         NaN       3.16
# 445         True    172.34       104.42        103.22         NaN       3.01
# ...

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# ## Vérification de corrélation entre les variables

# %%
data.drop(columns=["is_genuine"]).corr()
# Out:
#               diagonal  height_left  height_right  margin_low  margin_up  \
# diagonal      1.000000     0.019472     -0.024492   -0.111534  -0.055649
# height_left   0.019472     1.000000      0.242279    0.302643   0.246522
# height_right -0.024492     0.242279      1.000000    0.391085   0.307005
# margin_low   -0.111534     0.302643      0.391085    1.000000   0.431606
# margin_up    -0.055649     0.246522      0.307005    0.431606   1.000000
# length        0.097587    -0.320863     -0.401751   -0.666753  -0.520575
#
#                 length
# diagonal      0.097587
# height_left  -0.320863
# height_right -0.401751
# margin_low   -0.666753
# margin_up    -0.520575
# length        1.000000

# %%
sns.set(rc={'figure.figsize': (10, 8)}, font_scale=1.4)
sns.heatmap(data.drop(columns=["is_genuine"]).corr(
), linewidths=0.05, vmin=-1, vmax=1, annot=True)

plt.title('Corrélation des variables')
plt.show()

# %% [markdown]
# On fait d'abord vérifier s'il y a des corrélations entre les variables, s'il y en a, on peut appliquer la méthode de régression linéaire multivarié, afin pour remplacer les valeurs manquantes. On peut voir qu'il y a un peu de corrélation entre les variables, mais pas assez forte. On va quand même essayer avec le modèle de régression linéaire multivarié pour voir qu'est ce que cela donne.

# %% [markdown]
# ## Création de modèle régression linéaire

# %% [markdown]
# ### Régression linéaire avec la librairie Sklearn

# %%
# Création de model régression linéaire multivarié pour déterminer les valeurs manquantes
Data_model = data.drop(Null.index)

X = Data_model.drop(columns=["is_genuine",'margin_low'])
Y = Data_model['margin_low']

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.8, random_state=10)

# %%
X_train.shape
# Out:
# (1170, 5)

# %%
X_test.shape
# Out:
# (293, 5)

# %%
lin_reg = linear_model.LinearRegression()
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = lin_reg.predict(X_test)
lin_reg.score(X_train, Y_train)
# Out:
# 0.4606184927695156

# %%
lin_reg.score(X_test, Y_test)
# Out:
# 0.5404416684919964

# %% [markdown]
# En appliquant le model de régression linéaire, on a un coeffient de détermination à 46%, soit coefficient de détermination sur les données de test à 54%. Je trouve que le pouvoir de prédire de ce model n'est pas assez forte pour déterminer les valeurs manquantes. On va ajouter la variable 'is_genuine' qui distingue les vrais et faux billets pour vois si ce sera mieux.

# %%
X = Data_model.drop(columns=['margin_low'])
Y = Data_model['margin_low']

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.8, random_state=10)
lin_reg = linear_model.LinearRegression()
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = lin_reg.predict(X_test)
lin_reg.score(X_train, Y_train)
# Out:
# 0.6093593674078632

# %%
lin_reg.score(X_test, Y_test)
# Out:
# 0.6429607879346595

# %% [markdown]
# J'essaie d'ajouter la variable 'is_genuine' qui distingue les vrais et faux billets, et refaire le modèle, donc, on a un coeffient de détermination à 61%, soit coefficient de détermination sur les données de test à 64%. C'est beaucoup mieux, même si ce n'est pas très élevé, mais il présente quand même une prédiction assez parlante.

# %% [markdown]
# ### Régression linéaire avec la librairie Statsmodels

# %%
X = Data_model.drop(columns=["is_genuine",'margin_low'])
Y = Data_model['margin_low']
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.8, random_state=10)
X_train = sm.add_constant(X_train)
model = sm.OLS(Y_train, X_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     198.8
# Date:                Tue, 01 Mar 2022   Prob (F-statistic):          3.05e-153
# Time:                        15:50:57   Log-Likelihood:                -815.42
# No. Observations:                1170   AIC:                             1643.
# Df Residuals:                    1164   BIC:                             1673.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           24.3796     10.886      2.240      0.025       3.022      45.737
# ...

# %%
X = Data_model.drop(columns=['margin_low']).astype(float)
Y = Data_model['margin_low']
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.8, random_state=10)
X_train = sm.add_constant(X_train)
model = sm.OLS(Y_train, X_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.607
# Method:                 Least Squares   F-statistic:                     302.4
# Date:                Tue, 01 Mar 2022   Prob (F-statistic):          2.63e-233
# Time:                        15:50:57   Log-Likelihood:                -626.67
# No. Observations:                1170   AIC:                             1267.
# Df Residuals:                    1163   BIC:                             1303.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.1527      9.313      0.553      0.580     -13.119      23.425
# ...

# %%
X_test = sm.add_constant(X_test)
Y_predict = result.predict(X_test)
print("Le coefficient de détermination sur les données de test = {}%".format(
    round((r2_score(Y_test, Y_predict)*100), 2)))
# Out:
# Le coefficient de détermination sur les données de test = 64.3%
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# J'essaie d'utiliser la librairie Statsmodels pour faire une régression linéaire multivarié. On a le même résultat, un coeffient de détermination à 61%, soit une prédiction correcte sur les données de test à 64%.  On va utiliser ce modèle pour déterminer les 37 valeurs manquantes.

# %% [markdown]
# ## Remplacement des valeurs manquantes

# %%
# Remplacement les valeurs manquantes par la prédiction du régression linéaire
VNan = Null.drop(columns=['margin_low'])
billets = data
billets.loc[Null.index,('margin_low')] = lin_reg.predict(VNan).round(2)
billets
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %%
billets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1500 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
# Vérification si les valeurs manquantes sont bien remplacées par une interpolation linéaire
billets.loc[Null.index]
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72          True    171.94       103.89        103.45        4.06       3.25
# 99          True    171.93       104.07        104.18        4.11       3.14
# 151         True    172.07       103.80        104.38        4.12       3.02
# 197         True    171.45       103.66        103.80        3.99       3.62
# 241         True    171.83       104.14        104.06        4.13       3.02
# 251         True    171.80       103.26        102.82        4.12       2.95
# 284         True    171.92       103.83        103.76        4.08       3.23
# 334         True    171.85       103.70        103.96        4.13       3.00
# 410         True    172.56       103.72        103.51        4.07       3.12
# 413         True    172.30       103.66        103.50        4.07       3.16
# 445         True    172.34       104.42        103.22        4.13       3.01
# ...

# %%
billets['is_genuine'].value_counts()
# Out:
# True     1000
# False     500
# Name: is_genuine, dtype: int64

# %%
billets.groupby("is_genuine").mean()
# Out:
#              diagonal  height_left  height_right  margin_low  margin_up  \
# is_genuine
# False       171.90116    104.19034     104.14362     5.21622    3.35016
# True        171.98708    103.94913     103.80865     4.11631    3.05213
#
#                length
# is_genuine
# False       111.63064
# True        113.20243

# %% [markdown]
# Notre échantillon contient 1500 billets : 1000 vrais billets et 500 faux.
#
# Portrait-robot du vrai billet :
#
# - Diagonale : 171.99 mm.
# - Hauteur mesurée à gauche : 103.95 mm,
# - Hauteur mesurée à droite : 103.81 mm,
# - Marge entre le bord inférieur et le bord de l'image : 4.12 mm,
# - Marge entre le bord supérieur et le bord de l'image : 3.05 mm,
# - Longueur : 113.20 mm,
#
# Parmi les variables, il y a de grand différent pour les varibles 'margin_low' et 'length' entre un vrai et un faux billet.

# %% [markdown]
# # ACP et K-Means

# %% [markdown]
# ## ACP Analyse

# %% [markdown]
# ### Préparation des données centrées et réduites

# %%
# Préparation des données pour l'ACP
X = billets.drop(columns=["is_genuine"]).values

# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)
X_scaled
# Out:
# array([[-0.48653957,  2.77412327,  3.16324041,  0.05617478, -1.128325  ,
#          0.17365114],
#        [-1.63372936, -2.23653528, -0.79966777, -1.08086427, -0.69679916,
#          0.47166629],
#        [ 2.3978233 ,  1.50475644, -1.29119126, -0.12575147, -0.91256208,
#          0.55190114],
#        ...,
#        [-0.51931643, -0.06524991,  0.61346228,  1.55706633,  0.89984645,
#         -0.83501554],
#        [ 0.3328817 ,  0.83666863,  0.42914097,  1.04160863,  1.33137229,
#         -0.4911519 ],
#        [-1.6009525 ,  0.40241156, -0.30814427,  0.22294051,  0.94299904,
#         -0.69747008]])

# %% [markdown]
# ### Éboulis des valeurs propres

# %%
# Définition de la fonction pour le graphique Éboulis des valeurs propres

def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(), c="red", marker='o')
    plt.xlabel("Rang de l'axe d'inertie")
    plt.ylabel("Pourcentage d'inertie(%)")
    plt.title("Éboulis des valeurs propres")
    plt.show(block=False)

# Nombre de composants souhaités
n_comp = 6

# Calcul des composantes principales
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)

display_scree_plot(pca)
plt.show()

# %%
# Proportion de variance expliquée
pca.explained_variance_ratio_
# Out:
# array([0.43201658, 0.16957859, 0.13018767, 0.11823888, 0.09669064,
#        0.05328764])

# %% [markdown]
# Cet éboulis indique que l'axe F1 et F2 ont une grande inertie de presque 60%. On va s'intéresser aux axes F1 et F2.

# %% [markdown]
# ### Cercle de corrélation

# %%
from matplotlib.collections import LineCollection

# Définition de la fonction pour le graphique Cercle de corrélation


def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks:  # On affiche les 3 premiers plans factoriels, donc les 6 premières composantes
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(10, 10))

            # détermination des limites du graphique
            if lims is not None:
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30:
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else:
                xmin, xmax, ymin, ymax = min(pcs[d1, :]), max(
                    pcs[d1, :]), min(pcs[d2, :]), max(pcs[d2, :])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30:
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                           pcs[d1, :], pcs[d2, :],
                           angles='xy', scale_units='xy', scale=1, color="grey")
            else:
                lines = [[[0, 0], [x, y]] for x, y in pcs[[d1, d2]].T]
                ax.add_collection(LineCollection(
                    lines, axes=ax, alpha=.1, color='black'))

            # affichage des noms des variables
            if labels is not None:
                for i, (x, y) in enumerate(pcs[[d1, d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax:
                        plt.text(x, y, labels[i], fontsize='14', ha='center',
                                 va='center', rotation=label_rotation, color="blue", alpha=0.5)

            # affichage du cercle
            circle = plt.Circle((0, 0), 1, facecolor='none', edgecolor='b')
            plt.gca().add_artist(circle)

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)

            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(
                d1+1, round(100*pca.explained_variance_ratio_[d1], 1)))
            plt.ylabel('F{} ({}%)'.format(
                d2+1, round(100*pca.explained_variance_ratio_[d2], 1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)


# Cercle des corrélations

n_comp = 2
pcs = pca.components_
display_circles(pcs, n_comp, pca, [(0, 1)],
                labels=np.array(billets.columns[1:7]))

plt.show()

# %% [markdown]
# Analyse cercle des corrélations:
#
# - diagonal semble le mieux représenté, très corrélé à la dimension 2
# - les height et margin semblent corrélées entre elles mais faiblement avec la dimension 1
# - je note également une anti corrélation de la length sur la dimension 1

# %% [markdown]
# ### Projection des individus sur le plan factoriel selon le type de billet

# %%
# Définition de la fonction pour le graphique Projection des individus sur les plans factoriels

def display_factorial_planes(X_projected, n_comp, pca, axis_ranks, labels=None, alpha=1, illustrative_var=None):
    for d1, d2 in axis_ranks:
        if d2 < n_comp:

            # initialisation de la figure
            fig = plt.figure(figsize=(10, 10))

            # affichage des points
            if illustrative_var is None:
                plt.scatter(X_projected[:, d1],
                            X_projected[:, d2], alpha=alpha)
            else:
                illustrative_var = np.array(illustrative_var)
                for value in np.unique(illustrative_var):
                    selected = np.where(illustrative_var == value)
                    plt.scatter(
                        X_projected[selected, d1], X_projected[selected, d2], alpha=alpha, label=value)
                plt.legend()

            # affichage des labels des points
            if labels is not None:
                for i, (x, y) in enumerate(X_projected[:, [d1, d2]]):
                    plt.text(x, y, labels[i],
                             fontsize='14', ha='center', va='center')

            # détermination des limites du graphique
            boundary = np.max(np.abs(X_projected[:, [d1, d2]])) * 1.1
            plt.xlim([-boundary, boundary])
            plt.ylim([-boundary, boundary])

            # affichage des lignes horizontales et verticales
            plt.plot([-100, 100], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-100, 100], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(
                d1+1, round(100*pca.explained_variance_ratio_[d1], 1)))
            plt.ylabel('F{} ({}%)'.format(
                d2+1, round(100*pca.explained_variance_ratio_[d2], 1)))

            plt.title(
                "Projection des individus (sur F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)


# Projection des individus sur F1 et F2
X_projected = pca.transform(X_scaled)
display_factorial_planes(X_projected, n_comp, pca, [
                         (0, 1)], illustrative_var=billets.is_genuine)

# %% [markdown]
# On peut observer que la projection des individus sur le premier plan factoriel, qui distingue plutôt bien les vrai et faux billets.

# %% [markdown]
# ## Kmeans Analyse

# %% [markdown]
# ### Récupération des clusters attribués à chaque individu

# %%
# Classification méthode Kmeans
km = KMeans(2, random_state=10)
km.fit(X_scaled)

# Récupération des clusters attribués à chaque individu
billets["Clusters"] = km.labels_
billets
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length  Clusters
# ...

# %% [markdown]
# ### Comparaison de moyen des variables entre clusters et le type de billet

# %%
billets.groupby("Clusters").mean().drop("is_genuine", axis=1)
# Out:
#             diagonal  height_left  height_right  margin_low  margin_up  \
# Clusters
# 0         171.899153   104.200383    104.152520    5.221734   3.351734
# 1         171.987729   103.945129    103.805588    4.117968   3.052540
#
#               length
# Clusters
# 0         111.630847
# 1         113.196066

# %%
sns.pairplot(billets.drop("is_genuine", axis=1), hue='Clusters',
             corner=True).fig.suptitle('Pairplot par clusters')

plt.show()

# %%
billets.groupby("is_genuine").mean().drop("Clusters", axis=1)
# Out:
#              diagonal  height_left  height_right  margin_low  margin_up  \
# is_genuine
# False       171.90116    104.19034     104.14362     5.21622    3.35016
# True        171.98708    103.94913     103.80865     4.11631    3.05213
#
#                length
# is_genuine
# False       111.63064
# True        113.20243

# %%
sns.pairplot(billets.drop("Clusters", axis=1), hue='is_genuine',
             corner=True).fig.suptitle('Pairplot par type de billet')

plt.show()

# %% [markdown]
# Selon ce comparaison de moyen de chaque variable , les groupes créés par KMeans sont très proches de la distinction de vrai et faux billets, donc, cluster 0 correspond à faux billet, et cluster 1 sont de vrai.

# %% [markdown]
# ### Projection des individus sur le premier plan factoriel par clusters

# %%
# Affichage du clustering par projection des individus sur le premier plan factoriel

display_factorial_planes(X_projected, n_comp, pca, [
                         (0, 1)], illustrative_var=billets.Clusters)

# %% [markdown]
# Visuellement, sur le graphique, les clusters sont aussi très similaire par rapport à la distinction de vrai et faux billets, donc, cluster 0 correspond à faux billet, et cluster 1 est de vrai.

# %% [markdown]
# ### Matrice de confusion Kmeans

# %%
conf_matrix = pd.crosstab(billets.is_genuine, km.labels_)

# Representation graphique de notre matrice de confusion
sns.set(rc={'figure.figsize': (6, 6)}, font_scale=1.4)
sns.heatmap(conf_matrix, annot = True, fmt='', cmap='Blues', cbar=False)

plt.title('Matrice de confusion')
plt.xlabel('Clusters')
plt.ylabel('Type de billet')
plt.show()

# %% [markdown]
# On fait une analyse des nombres de faux via une matrix de confusion, en comparant les deux clusters avec la distinction original des vrais et faux billets. Donc, ici, nous avons 10 vrais billets détectés comme des faux billets (cluster 0), et 14 faux billets détectés comme des vrais billets (cluster 1). On va ensuite ajouter les données de test pour voir si on peut bien détecter des faux billets à l'aide de KMeans.

# %% [markdown]
# ### Tester les billets inconnus

# %% [markdown]
# #### Importation des données de test

# %%
# Importation des données de test
b = pd.read_csv(
    'Desktop/Openclassrooms/P10_Shibin_YANG/billets_production.csv', sep=',')
b
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5

# %% [markdown]
# #### Combiner les données inconnues avec les données d'origine

# %%
# Combiner les données inconnues avec les données d'origine avant centré et réduit
billets_plus = pd.concat([billets.drop("Clusters", axis = 1), b])
billets_plus
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
# ..        ...       ...          ...           ...         ...        ...
# 0         NaN    171.76       104.01        103.54        5.21       3.30
# 1         NaN    171.87       104.17        104.13        6.00       3.31
# 2         NaN    172.00       104.58        104.29        4.99       3.39
# 3         NaN    172.49       104.55        104.34        4.44       3.03
# 4         NaN    171.65       103.63        103.56        3.77       3.16
#
#     length   id
# 0   112.83  NaN
# 1   113.09  NaN
# 2   113.16  NaN
# ...

# %% [markdown]
# #### Préparation des données de test (centrées et réduites)

# %%
# Préparation des données de test pour l'ACP
z = billets_plus.drop(columns = ["is_genuine", "id"]).values

# Centrage et Réduction avec les données d'origine pour ne biaise pas le résultat
std_scale = preprocessing.StandardScaler().fit(z)
z_scaled = std_scale.transform(z)
z_scaled
# Out:
# array([[-0.4865586 ,  2.76923391,  3.16170796,  0.05410626, -1.13061318,
#          0.17500507],
#        [-1.63390724, -2.23576629, -0.79994111, -1.08170256, -0.69868709,
#          0.47301405],
#        [ 2.39820372,  1.50130053, -1.29130844, -0.12762315, -0.91465013,
#          0.55324723],
#        ...,
#        [ 0.13628781,  1.83496721,  1.13481774,  0.76587979,  1.02901727,
#         -1.26919229],
#        [ 1.74257592,  1.7348672 ,  1.28837003, -0.06704668, -0.52591665,
#          0.59909477],
#        [-1.01106084, -1.33486626, -1.10704569, -1.08170256,  0.03558727,
#          0.74809926]])

# %% [markdown]
# #### Projection des individus d'origine par clusters, et les individus inconnus sur le plan factoriel

# %%
# Projection des individus d'origine, en ajoutant les individus inconnus sur F1 et F2
# Comparer avec les clusters

z_projected = pca.transform(z_scaled[-5:])

clusters = km.labels_

sns.set(rc={'figure.figsize': (10, 10)}, font_scale=1.4)
sns.scatterplot(x=X_projected[:, 0], y=X_projected[:,
                1], hue=clusters, s=50, palette='Set2')
sns.scatterplot(x=z_projected[:, 0], y=z_projected[:, 1], palette=['darkviolet', 'yellow',
                'brown', 'dodgerblue', 'black'], hue=billets_plus.id[-5:], s=100)
plt.legend()
plt.title("Projection des individus sur le 1e plan factoriel de PCA")

# Affichage des positions des centres de classes
centroids = km.cluster_centers_
centroids_projected = pca.transform(centroids)
plt.scatter(centroids_projected[:, 0], centroids_projected[:, 1],
            marker="o", c="white", alpha=1, s=200, edgecolor="k")
for i, c in enumerate(centroids_projected):
    plt.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

# affichage des lignes horizontales et verticales
plt.plot([-4, 5], [0, 0], color='grey', ls='--')
plt.plot([0, 0], [-4, 5], color='grey', ls='--')

# définition des limites du graphique
plt.xlim([-4, 5])
plt.ylim([-4, 5])

plt.show(block=False)

# %% [markdown]
# On peut quasiment d'être sûr que les billets 'A_1', 'A_2', 'A_3' sont dans le cluster 0, certainement ils sont des faux billets, les billets 'A_4', 'A_5' sont dans le cluster 1, certainement ils sont des vrais billets. On va essayer de chercher pour chaque individu de test, le plus proche de centoid des deux clusters.

# %% [markdown]
# #### Prédiction par Kmeans

# %%
# Prédiction par Kmeans
y_kmeans = km.predict(z_scaled[-5:])
verif = pd.DataFrame(y_kmeans, index=billets_plus.id[-5:],
                     columns=['Clusters']).reset_index()
verif
# Out:
#     id  Clusters
# 0  A_1         0
# 1  A_2         0
# 2  A_3         0
# 3  A_4         1
# 4  A_5         1

# %% [markdown]
# #### Calcul de la distance entre chaque billet inconnu et le centre des clusters

# %%
# Vérification de la projection de centroids
centroids_projected
# Out:
# array([[ 2.06704432, -0.07421998, -0.09135135, -0.08668897, -0.13922759,
#         -0.04720493],
#        [-1.0211693 ,  0.03666644,  0.04512975,  0.04282642,  0.06878176,
#          0.02332036]])

# %%
# Vérification de centroids
centroids
# Out:
# array([[-0.19432338,  0.57071311,  0.71336493,  1.12003987,  0.86417597,
#         -1.20083284],
#        [ 0.09600039, -0.28194592, -0.35241933, -0.55332647, -0.42692359,
#          0.59324013]])

# %%
from scipy.spatial import distance_matrix

# Vérification des billets à l'aide de distance entre chaque individu et les deux centroids
dist_mat = pd.DataFrame(distance_matrix(z_scaled[-5:], centroids), index=billets_plus.id[-5:], columns=[
                        'Centroid_0', 'Centroid_1']).reset_index()
dist_mat
# Out:
#     id  Centroid_0  Centroid_1
# 0  A_1    2.065007    3.045863
# 1  A_2    1.310503    3.557206
# 2  A_3    1.429174    3.744802
# 3  A_4    3.466805    3.117248
# 4  A_5    4.116400    1.849531

# %% [markdown]
# On a donc le résultat, les billets 'A_1', 'A_2', 'A_3' sont des faux billets, car ils sont plus proche du centroid de cluster 0, et les billets 'A_4', 'A_5' sont des vrais, ils sont proche du centroid de cluster 1.
#
# On va créer un model pour détecter les billets inconnus, en utilisant la distance minimale entre chaque billets inconnus et les controids des clusters pour réaliser la prédiction.

# %% [markdown]
# ## Script de modèle de détection Kmeans

# %%
def verif_billets_model_kmeans(csv):
    bills = pd.read_csv(csv)
    id_bills = bills["id"]
    billets_plus = pd.concat([billets.drop("Clusters", axis = 1), bills])
    bills_val = billets_plus.drop(columns = ["is_genuine", "id"]).values
    test = preprocessing.StandardScaler().fit(bills_val[-5:])
    test_scaled = test.transform(bills_val[-5:])
    dist = pd.DataFrame(distance_matrix(test_scaled, centroids), index=bills["id"], columns=[
                        'Centroid_0', 'Centroid_1']).reset_index()
    predictions = dist["Centroid_0"] > dist["Centroid_1"]

    for i in range(len(bills)):
        print("billets {} : c'est un vrai billet = {}".format(
            id_bills[i], predictions[i]))

# %%
verif_billets_model_kmeans("Desktop/Openclassrooms/P10_Shibin_YANG/billets_production.csv")
# Out:
# billets A_1 : c'est un vrai billet = False
# billets A_2 : c'est un vrai billet = False
# billets A_3 : c'est un vrai billet = False
# billets A_4 : c'est un vrai billet = True
# billets A_5 : c'est un vrai billet = True

# %%
verif_billets_model_kmeans("Desktop/Openclassrooms/P10_Shibin_YANG/billets_test.csv")
# Out:
# billets B_1 : c'est un vrai billet = True
# billets B_2 : c'est un vrai billet = False
# billets B_3 : c'est un vrai billet = True
# billets B_4 : c'est un vrai billet = False
# billets B_5 : c'est un vrai billet = False

# %% [markdown]
# Pour être sûr de ce résultat, on va encore essayer les autres méthodes.

# %% [markdown]
# # Régression logistique

# %% [markdown]
# ## Régression logistique avec la librairie Sklearn

# %% [markdown]
# ### Séparation des données d'entraînement et de test

# %% [markdown]
# Pour appliquer cette méthode, nous allons séparer le jeu de données en training set et testing set. J'ai mis la répartition classique 80/20 entre training et testing set, c'est-à-dire que je vais fixer les données d'entrainement à 1200 individus, et les données de test à 300 individus.

# %%
# Création de modèle d'entraînement
model_logit_reg = linear_model.LogisticRegression()

X = billets.loc[:, "diagonal":"length"]
Y = billets.is_genuine

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(
    X, Y, train_size=0.8, random_state=0)

# %%
Xtest.shape
# Out:
# (300, 6)

# %%
Xtrain.shape
# Out:
# (1200, 6)

# %% [markdown]
# ### Création de modèle régression logistique

# %%
model_logit_reg.fit(Xtrain, Ytrain)
# Out:
# LogisticRegression()

# %%
print("Le coefficient de détermination du model: {} %".format(
    round((model_logit_reg.score(Xtrain, Ytrain)*100), 2)))
# Out:
# Le coefficient de détermination du model: 98.92 %

# %% [markdown]
# ### Évaluation du modèle avec les données de test

# %%
# "accuracy_score" utilisé pour évaluer le score de classification de la prédiction (nos cas : Vrai ou faux)
# Si on calcul le taux de prédiction correcte sur les données de test

Y_predict = model_logit_reg.predict(Xtest)
print("Le taux de prédiction correcte sur les données de test = {}%".format(
    round((accuracy_score(Ytest, Y_predict)*100), 2)))
# Out:
# Le taux de prédiction correcte sur les données de test = 99.67%

# %%
# "r2_score" calcule le coefficient de détermination, utilisé pour les valeurs continues (nombres réels)
# Si on veut vraiment utiliser "r2_score", faut transformer les valeurs prédiction en nombre réels
# Par contre, comme on le transforme en int, le résultat va être influencé
# Par example, on calcul le taux de prédiction correcte sur les données de test

Y_predict_transfor = Y_predict.astype(int)
print("Le coefficient de détermination sur les données de test = {}%".format(
    round((r2_score(Ytest, Y_predict_transfor)*100), 2)))
# Out:
# Le coefficient de détermination sur les données de test = 98.48%

# %% [markdown]
# ### Matrice de confusion régression logistique

# %%
# Matrix de confusion sur les données de test
conf_matrix = pd.DataFrame(confusion_matrix(Ytest, Y_predict), index=[
                           'False', 'True'], columns=['False', 'True'])

# Representation graphique de notre matrice de confusion
sns.set(rc={'figure.figsize': (6, 6)}, font_scale=1.4)
sns.heatmap(conf_matrix, annot=True, fmt='', cmap='Blues', cbar=False)

plt.title('Matrice de confusion (Données de test)')
plt.xlabel('Prediction label')
plt.ylabel('Vrai label')
plt.show()

# %% [markdown]
# En appliquant la méthode de régression logistique avec les données de test, selon la matrice de confusion, nous avons 0 vrai billet détecté comme de faux billet, et 1 faux billet détecté comme de vrai billet. On a le coefficient de déterminationle qui est égale 0.99, cela signifie que le taux de prédiction d'un billet sera correcte s'éleve à 99%,

# %% [markdown]
# ### Coefficient régression logistique

# %%
pd.DataFrame(np.concatenate([model_logit_reg.intercept_.reshape(-1, 1), model_logit_reg.coef_],
             axis=1), index=["coef"], columns=["constante"]+list(X.columns)).T
# Out:
#                   coef
# constante    -0.017673
# diagonal     -0.046297
# height_left  -1.547336
# height_right -2.071765
# margin_low   -3.400010
# margin_up    -3.288560
# length        3.651367

# %% [markdown]
# ## Script de modèle de détection régression logistique - 1

# %%
def verif_model_logiR1(csv):
    bills = pd.read_csv(csv)
    id_bills = bills["id"]
    bills_val = bills.loc[:, "diagonal":"length"]
    predictions = model_logit_reg.predict_proba(bills_val)
    for i in range(len(bills)):
        print("billets {} : probabilité que le billet soit vrai = {}%".format(
            id_bills[i], round(((predictions[i][1])*100), 2)))

# %%
verif_model_logiR1("Desktop/Openclassrooms/P10_Shibin_YANG/billets_production.csv")
# Out:
# billets A_1 : probabilité que le billet soit vrai = 0.58%
# billets A_2 : probabilité que le billet soit vrai = 0.1%
# billets A_3 : probabilité que le billet soit vrai = 0.14%
# billets A_4 : probabilité que le billet soit vrai = 91.13%
# billets A_5 : probabilité que le billet soit vrai = 99.96%

# %% [markdown]
# On va donc détecter les billets inconnus, on a donc le résultat, les billets 'A_1', 'A_2', 'A_3' sont des faux billets, et les billets 'A_4', 'A_5' sont des vrais.

# %%
verif_model_logiR1("Desktop/Openclassrooms/P10_Shibin_YANG/billets_test.csv")
# Out:
# billets B_1 : probabilité que le billet soit vrai = 98.87%
# billets B_2 : probabilité que le billet soit vrai = 0.92%
# billets B_3 : probabilité que le billet soit vrai = 99.9%
# billets B_4 : probabilité que le billet soit vrai = 0.02%
# billets B_5 : probabilité que le billet soit vrai = 1.38%

# %% [markdown]
# ## Régression logistique avec la librairie Statsmodels

# %% [markdown]
# ### Séparation des données d'entraînement et de test

# %%
x = billets.loc[:, "diagonal":"length"]
y = billets.is_genuine

# Séparation des données d'entrainement et des données de test
x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size=0.8, random_state=5)

# %% [markdown]
# ### Création de modèle régression logistique

# %%
# Création de model
x_train = sm.add_constant(x_train)
model = sm.Logit(y_train, x_train)
result = model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.024266
#          Iterations 14
#                            Logit Regression Results
# ...
# Dep. Variable:             is_genuine   No. Observations:                 1200
# Model:                          Logit   Df Residuals:                     1193
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 01 Mar 2022   Pseudo R-squ.:                  0.9616
# Time:                        15:51:04   Log-Likelihood:                -29.119
# converged:                       True   LL-Null:                       -758.87
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -187.8962    290.180     -0.648      0.517    -756.638     380.846
# ...

# %% [markdown]
# ### Évaluation du modèle avec les données de test

# %%
# Tester la prédiction avec les données de test
x_test = sm.add_constant(x_test)
y_predict = result.predict(x_test)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
# Le coefficient de détermination sur les données de test
print("Le coefficient de détermination sur les données de test = {}%".format(
    round((r2_score(y_test, y_predict)*100), 2)))
# Out:
# Le coefficient de détermination sur les données de test = 95.35%

# %%
# Si on veut savoir le score de prédiction après arrondir le résultat de prédiction
# Par contre, comme on le transforme en int, le résultat va être influencé

prediction = list(map(round, y_predict))
print("Le taux de prédiction correcte sur les données de test = {}%".format(
    round((accuracy_score(y_test, prediction)*100), 2)))
# Out:
# Le taux de prédiction correcte sur les données de test = 98.33%

# %% [markdown]
# ### Matrice de confusion régression logistique

# %%
# Matrix de confusion sur les données de test
conf_matrix = pd.DataFrame(confusion_matrix(y_test, prediction), index=[
                           'False', 'True'], columns=['False', 'True'])

# Representation graphique de notre matrice de confusion
sns.set(rc={'figure.figsize': (6, 6)}, font_scale=1.4)
sns.heatmap(conf_matrix, annot=True, fmt='', cmap='Blues', cbar=False)

plt.title('Matrice de confusion (Données de test)')
plt.xlabel('Prediction label')
plt.ylabel('Vrai label')
plt.show()

# %% [markdown]
# J'essaye d'appliquer la régression logistique avec un autre librairie Statsmodels, on a R2 : le coefficient de détermination qui est à peu près 0.96, 95% sur les données de test, c'est aussi pas mal. Selon la matrice de confusion, nous avons 3 vrais billets détectés comme des faux billets, et 2 faux billets détectés comme des vrais billets.

# %% [markdown]
# ## Script de modèle de détection régression logistique - 2

# %%
def verif_model_logiR2(csv):
    bills = pd.read_csv(csv)
    id_bills = bills["id"]
    bills_val = bills.loc[:, "diagonal":"length"]
    bills_val = sm.add_constant(bills_val)
    predictions = result.predict(bills_val)
    for i in range(len(bills)):
        print("billets {} : probabilité que le billet soit vrai = {}%".format(
            id_bills[i], round(((predictions[i])*100), 2)))

# %%
verif_model_logiR2("Desktop/Openclassrooms/P10_Shibin_YANG/billets_production.csv")
# Out:
# billets A_1 : probabilité que le billet soit vrai = 0.0%
# billets A_2 : probabilité que le billet soit vrai = 0.0%
# billets A_3 : probabilité que le billet soit vrai = 0.0%
# billets A_4 : probabilité que le billet soit vrai = 99.38%
# billets A_5 : probabilité que le billet soit vrai = 100.0%
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# On va aussi détecter les billets inconnus, on a donc le même résultat, les billets 'A_1', 'A_2', 'A_3' sont des faux billets, et les billets 'A_4', 'A_5' sont des vrais.
#
# On va essayer encore la méthode KNN pour vérifier si la détection de ce model est correcte.

# %%
verif_model_logiR2("Desktop/Openclassrooms/P10_Shibin_YANG/billets_test.csv")
# Out:
# billets B_1 : probabilité que le billet soit vrai = 99.93%
# billets B_2 : probabilité que le billet soit vrai = 0.01%
# billets B_3 : probabilité que le billet soit vrai = 100.0%
# billets B_4 : probabilité que le billet soit vrai = 0.0%
# billets B_5 : probabilité que le billet soit vrai = 0.07%

# %% [markdown]
# # K Nearest Neighbors (K-NN)

# %% [markdown]
# ## Séparation des données d'entraînement et de test

# %% [markdown]
# On va maintenant essayer la méthode K-NN, c’est un algorithme qui peut servir autant pour la classification que pour la régression. Il est surnommé « nearest neighbors » (plus proches voisins, en français) car le principe de ce modèle consiste en effet à choisir les k données les plus proches du point étudié afin d’en prédire sa valeur.
#
# Pour l'appliquer, nous allons séparer le jeu de données en training set et testing set comme précédent. J'ai mis la répartition classique 80/20 entre training et testing set.

# %%
x = billets.select_dtypes(np.number).drop(["Clusters"], axis=1)
y = billets.is_genuine

xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, train_size=0.8, random_state=10)

# %%
xtest.shape
# Out:
# (300, 6)

# %%
xtrain.shape
# Out:
# (1200, 6)

# %% [markdown]
# ## Calcul le nombre optimal de K

# %%
errors = []
for k in range(2,15):
    knn = neighbors.KNeighborsClassifier(k)
    errors.append(100*(1 - knn.fit(xtrain, ytrain).score(xtest, ytest)))
plt.figure(figsize=(10, 10))
plt.plot(range(2,15), errors, 'o-')
plt.title('Nombre optimal de K')
plt.ylabel("Taux d'erreur de prédiction")
plt.xlabel('Nombre de K')
plt.show()

# %% [markdown]
# Le k (nombre de voisins) est l'hyper-paramètre que l’on va chercher à optimiser pour minimiser l’erreur sur les données test. Pour trouver le k optimal, on va simplement tester le modèle pour tous les k de 2 à 15, mesurer l’erreur test et afficher la performance en fonction de k.
#
# Comme on peut le voir, le k-NN le plus performant est celui pour lequel k = 5. On connaît donc notre classifieur final optimal : 5-NN. Ce qui veut dire que c'est celui qui classifie le mieux les données.

# %% [markdown]
#  ## Création de modèle 5-NN

# %%
# On récupère le classifieur le plus performant
knn = neighbors.KNeighborsClassifier(5)
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier()

# %%
# Le précision de la prédiction Knn
print("Le précision de la prédiction du model: {} %".format(
    round((knn.score(xtrain, ytrain)*100), 2)))
# Out:
# Le précision de la prédiction du model: 99.25 %

# %% [markdown]
# ## Évaluation du modèle avec les données de test

# %%
# On récupère les prédictions sur les données test
yprediction = knn.predict(xtest)

# %%
# On calcul le taux d'erreur de prédiction sur les données de test
error = 1 - knn.score(xtest, ytest)
print("Le taux d'erreur de prédiction sur les données de test: {} %".format(round((error*100), 2)))
# Out:
# Le taux d'erreur de prédiction sur les données de test: 0.67 %

# %%
print("Le taux de prédiction correcte sur les données de test = {}%".format(
    round((accuracy_score(ytest, yprediction)*100), 2)))
# Out:
# Le taux de prédiction correcte sur les données de test = 99.33%

# %%
print(classification_report(ytest, yprediction))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       105
#         True       0.99      1.00      0.99       195
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300

# %% [markdown]
# ## Matrice de confusion K-NN

# %%
# Matrix de confusion sur les données de test
conf_matrix = pd.DataFrame(confusion_matrix(ytest, yprediction), index=[
                           'False', 'True'], columns=['False', 'True'])

# Representation graphique de notre matrice de confusion
sns.set(rc={'figure.figsize': (6, 6)}, font_scale=1.4)
sns.heatmap(conf_matrix, annot=True, fmt='', cmap='Blues', cbar=False)

plt.title('Matrice de confusion (Données de test)')
plt.xlabel('Prediction label')
plt.ylabel('Vrai label')
# Out:
# Text(26.5, 0.5, 'Vrai label')

# %% [markdown]
# En appliquant la méthode de 5-NN, selon la matrice de confusion, pour les données de test, 0 vrai billet détecté comme de faux billet, et 2 faux billets détectés comme des vrais billets, le taux de prédiction d'un billet sera correcte s'éleve aussi à 99%.

# %% [markdown]
# ## Script de modèle de détection K-NN

# %%
def verif_model_knn(csv):
    bills = pd.read_csv(csv)
    id_bills = bills["id"]
    bills_val = bills.loc[:, "diagonal":"length"]
    predictions = knn.predict(bills_val)
    for i in range(len(bills)):
        print("billets {} : c'est un vrai billet = {}".format(
            id_bills[i], (predictions[i])))

# %%
verif_model_knn("Desktop/Openclassrooms/P10_Shibin_YANG/billets_production.csv")
# Out:
# billets A_1 : c'est un vrai billet = False
# billets A_2 : c'est un vrai billet = False
# billets A_3 : c'est un vrai billet = False
# billets A_4 : c'est un vrai billet = True
# billets A_5 : c'est un vrai billet = True

# %%
verif_model_knn("Desktop/Openclassrooms/P10_Shibin_YANG/billets_test.csv")
# Out:
# billets B_1 : c'est un vrai billet = True
# billets B_2 : c'est un vrai billet = False
# billets B_3 : c'est un vrai billet = True
# billets B_4 : c'est un vrai billet = False
# billets B_5 : c'est un vrai billet = False

# %% [markdown]
# On va détecter les billets inconnus, on a donc le même résultat, les billets 'A_1', 'A_2', 'A_3' sont des faux billets, et les billets 'A_4', 'A_5' sont des vrais. On peut aussi voir la probabilité de prédiction de chaque billet.

# %%
def verif_model_knn_proba(csv):
    bills = pd.read_csv(csv)
    id_bills = bills["id"]
    bills_val = bills.loc[:, "diagonal":"length"]
    predictions = knn.predict_proba(bills_val)
    for i in range(len(bills)):
        print("billets {} : probabilité que le billet soit vrai = {}%".format(
            id_bills[i], round(((predictions[i][1])*100), 2)))

# %%
verif_model_knn_proba("Desktop/Openclassrooms/P10_Shibin_YANG/billets_production.csv")
# Out:
# billets A_1 : probabilité que le billet soit vrai = 0.0%
# billets A_2 : probabilité que le billet soit vrai = 0.0%
# billets A_3 : probabilité que le billet soit vrai = 0.0%
# billets A_4 : probabilité que le billet soit vrai = 100.0%
# billets A_5 : probabilité que le billet soit vrai = 100.0%

# %%
verif_model_knn_proba("Desktop/Openclassrooms/P10_Shibin_YANG/billets_test.csv")
# Out:
# billets B_1 : probabilité que le billet soit vrai = 100.0%
# billets B_2 : probabilité que le billet soit vrai = 0.0%
# billets B_3 : probabilité que le billet soit vrai = 100.0%
# billets B_4 : probabilité que le billet soit vrai = 0.0%
# billets B_5 : probabilité que le billet soit vrai = 0.0%
